# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Hyperparameters — the quantities that define the structure of a network rather than the specific learned values.
# >- **Depth ($K$):** the number of hidden layers.
# >- **Width ($D_1, D_2, \ldots, D_K$):** the number of [[hidden units]] per layer.
# >- **Capacity:** total number of [[hidden units]]; roughly, how complex the network can be.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Based on the text and the provided image (Figure 4.6), the four hyperparameters that define this network's architecture are:
# - Depth ($K$): 3. This is the total number of hidden layers ($\mathbf{h}_1$, $\mathbf{h}_2$, and $\mathbf{h}_3$).
# - Width of 1st Hidden Layer ($D_1$): 4. This is the number of units in hidden layer $\mathbf{h}_1$.
# - Width of 2nd Hidden Layer ($D_2$): 2. This is the number of units in hidden layer $\mathbf{h}_2$.
# - Width of 3rd Hidden Layer ($D_3$): 3. This is the number of units in hidden layer $\mathbf{h}_3$.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Depth of the deep neural network is the number of hidden layers: 20
# The width(number of hidden untits per hidden layer): 20

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
